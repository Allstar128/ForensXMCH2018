# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE

# %%
df = pd.read_csv("Encoded_Data.csv")

# %%
df.head()
# Out:
#    Adjusted Grade  New?  Other Location Code in LCGMS  School Name  \
# 0               0     0                             0          475
# 1               0     0                             0          486
# 2               0     0                             0          490
# 3               0     0                             0          529
# 4               0     0                             0         1224
#
#    Location Code  Address (Full)  City  Grades  Grade Low  Grade High  \
# 0              0             605    27      33          9           3
# 1              1             301    27      33          9           3
# 2              2             254    27      33          9           3
# 3              3             941    27      35          9           6
# 4              4             100    27      33          9           3
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# ...

# %%
df = df.fillna(method='ffill')

# %%
X = df.drop(['Economic Need Index', 'Address (Full)', 'School Income Estimate', 'Location Code'], axis = 1)
X = df.drop(df.columns[:38], axis = 1)

# %%
tsne = TSNE(n_components=3, verbose = 2)

# %%
tsne_out = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1272 samples in 0.006s...
# [t-SNE] Computed neighbors for 1272 samples in 0.257s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1272
# [t-SNE] Computed conditional probabilities for sample 1272 / 1272
# [t-SNE] Mean sigma: 12.345835
# [t-SNE] Computed conditional probabilities in 0.132s
# [t-SNE] Iteration 50: error = 64.4088898, gradient norm = 0.1428847 (50 iterations in 5.480s)
# [t-SNE] Iteration 100: error = 58.4548798, gradient norm = 0.0716779 (50 iterations in 2.623s)
# [t-SNE] Iteration 150: error = 57.9853401, gradient norm = 0.0282803 (50 iterations in 2.812s)
# [t-SNE] Iteration 200: error = 57.9223557, gradient norm = 0.0420656 (50 iterations in 3.300s)
# [t-SNE] Iteration 250: error = 57.9666176, gradient norm = 0.0443842 (50 iterations in 3.639s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.966618
# ...

# %%
plt.figure(figsize = (16,9))
plt.scatter(tsne_out[:,0], tsne_out[:,1], c = df['Economic Need Index'])
plt.xlabel("TSNE1")
plt.ylabel('TSNE2')
plt.colorbar()

# %%
X.head()
# Out:
#    Adjusted Grade  New?  Other Location Code in LCGMS  School Name  \
# 0               0     0                             0          475
# 1               0     0                             0          486
# 2               0     0                             0          490
# 3               0     0                             0          529
# 4               0     0                             0         1224
#
#    Location Code  Address (Full)  City  Grades  Grade Low  Grade High  \
# 0              0             605    27      33          9           3
# 1              1             301    27      33          9           3
# 2              2             254    27      33          9           3
# 3              3             941    27      35          9           6
# 4              4             100    27      33          9           3
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# ...

# %%
print([x for x in X.columns])
# Out:
# ['Adjusted Grade', 'New?', 'Other Location Code in LCGMS', 'School Name', 'Location Code', 'Address (Full)', 'City', 'Grades', 'Grade Low', 'Grade High', 'Community School?', 'Rigorous Instruction Rating', 'Collaborative Teachers Rating', 'Supportive Environment Rating', 'Effective School Leadership Rating', 'Strong Family-Community Ties Rating', 'Trust Rating', 'Student Achievement Rating', 'SED Code', 'District', 'Latitude', 'Longitude', 'Zip', 'School Income Estimate', 'Percent ELL', 'Percent Asian', 'Percent Black', 'Percent Hispanic', 'Percent Black / Hispanic', 'Percent White', 'Student Attendance Rate', 'Percent of Students Chronically Absent', 'Rigorous Instruction %', 'Collaborative Teachers %', 'Supportive Environment %', 'Effective School Leadership %', 'Strong Family-Community Ties %', 'Trust %', 'Average ELA Proficiency', 'Average Math Proficiency', 'Grade 3 ELA - All Students Tested', 'Grade 3 ELA 4s - All Students', 'Grade 3 ELA 4s - American Indian or Alaska Native', 
# ...

# %%
k_means = pd.read_csv('Viraj/KMeansLabels.csv')

# %%
len(X.columns)
# Out:
# 158

# %%
print(X.columns[38:])
# Out:
# Index(['Grade 3 ELA - All Students Tested', 'Grade 3 ELA 4s - All Students',
#        'Grade 3 ELA 4s - American Indian or Alaska Native',
#        'Grade 3 ELA 4s - Black or African American',
#        'Grade 3 ELA 4s - Hispanic or Latino',
#        'Grade 3 ELA 4s - Asian or Pacific Islander', 'Grade 3 ELA 4s - White',
#        'Grade 3 ELA 4s - Multiracial',
#        'Grade 3 ELA 4s - Limited English Proficient',
#        'Grade 3 ELA 4s - Economically Disadvantaged',
#        ...
#        'Grade 8 Math - All Students Tested', 'Grade 8 Math 4s - All Students',
#        'Grade 8 Math 4s - American Indian or Alaska Native',
#        'Grade 8 Math 4s - Black or African American',
#        'Grade 8 Math 4s - Hispanic or Latino',
#        'Grade 8 Math 4s - Asian or Pacific Islander',
#        'Grade 8 Math 4s - White', 'Grade 8 Math 4s - Multiracial',
#        'Grade 8 Math 4s - Limited English Proficient',
#        'Grade 8 Math 4s - Economically Disadvantaged'],
# ...
