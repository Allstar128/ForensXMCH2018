# %%
import plotly
plotly.offline.init_notebook_mode()
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
from plotly.graph_objs import *
from plotly import tools
init_notebook_mode()
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import io
# %matplotlib inline
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
df = pd.read_csv('Encoded_Data.csv')
df.head()
# Out:
#    Adjusted Grade  New?  Other Location Code in LCGMS  School Name  \
# 0               0     0                             0          475
# 1               0     0                             0          486
# 2               0     0                             0          490
# 3               0     0                             0          529
# 4               0     0                             0         1224
#
#    Location Code  Address (Full)  City  Grades  Grade Low  Grade High  \
# 0              0             605    27      33          9           3
# 1              1             301    27      33          9           3
# 2              2             254    27      33          9           3
# 3              3             941    27      35          9           6
# 4              4             100    27      33          9           3
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# ...

# %%
corr = df.corr()

# %%
trace = Heatmap(z=np.array(corr),
                x = df.columns,
               y = df.columns[::-1])
data=[trace]
iplot(data)
# Out:
# <div id="49fa8ee2-4d2b-4926-9cc5-680866ccf3c0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("49fa8ee2-4d2b-4926-9cc5-680866ccf3c0", [{"x": ["Adjusted Grade", "New?", "Other Location Code in LCGMS", "School Name", "Location Code", "Address (Full)", "City", "Grades", "Grade Low", "Grade High", "Community School?", "Rigorous Instruction Rating", "Collaborative Teachers Rating", "Supportive Environment Rating", "Effective School Leadership Rating", "Strong Family-Community Ties Rating", "Trust Rating", "Student Achievement Rating", "SED Code", "District", "Latitude", "Longitude", "Zip", "Economic Need Index", "School Income Estimate", "Percent ELL", "Percent Asian", "Percent Black", "Percent Hispanic", "Percent Black / Hispanic", "Percent White", "Student Attendance Rate", "Percent of Students Chroni
# ...

# %%
plt.figure(figsize = (20,20))
sns.heatmap(corr)
#plt.savefig('corr.png', dpi = 500)

# %%
nf = df.drop(df.columns[41:160], axis = 1)

# %%
np.where(df.columns == "Grade 8 Math 4s - Economically Disadvantaged")
# Out:
# (array([160], dtype=int64),)

# %%
plt.figure(figsize = (20,20))
sns.heatmap(nf.corr())
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig('corrnogrades.png', dpi = 500)

# %%
plt.savefig('corrnogrades.png', dpi = 500)

# %%
trace = Heatmap(z=np.array(nf.corr()),
                x = nf.columns,
               y = nf.columns[::-1])
data=[trace]

fig = Figure(data=data, layout=layout)

iplot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2f67c5e9b9f9> in <module>()
#       4 data=[trace]
#       5
# ----> 6 fig = Figure(data=data, layout=layout)
#       7
#       8 iplot(data)
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames)
#     312                         respective traces in the data attribute
#     313         """
# --> 314         super(Figure, self).__init__(data, layout, frames)
#     315
#     316     def add_area(
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames)
#     155
#     156         # ### Import Layout ###
# --> 157         self._layout_obj = self._layout_validator.validate_coerce(layout)
#     158
#     159         # ### Import clone of layout properties ###
#
# ...

# %%
trace = Heatmap(z=np.array(nf.corr()),
                x = nf.columns,
               y = nf.columns[::-1])
data=[trace]
iplot(data)
# Out:
# <div id="5d8b6bb6-a548-44ee-9c37-1a542664b608" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5d8b6bb6-a548-44ee-9c37-1a542664b608", [{"x": ["Adjusted Grade", "New?", "Other Location Code in LCGMS", "School Name", "Location Code", "Address (Full)", "City", "Grades", "Grade Low", "Grade High", "Community School?", "Rigorous Instruction Rating", "Collaborative Teachers Rating", "Supportive Environment Rating", "Effective School Leadership Rating", "Strong Family-Community Ties Rating", "Trust Rating", "Student Achievement Rating", "SED Code", "District", "Latitude", "Longitude", "Zip", "Economic Need Index", "School Income Estimate", "Percent ELL", "Percent Asian", "Percent Black", "Percent Hispanic", "Percent Black / Hispanic", "Percent White", "Student Attendance Rate", "Percent of Students Chroni
# ...
